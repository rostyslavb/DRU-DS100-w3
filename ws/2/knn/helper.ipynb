# %%
# Out:
# (144, 2)
# Evaluating distancies started
# Distancies completed in 3 seconds for 656x144
# k=1, accuracy = 98.61111111111111%, time = 0.02301502227783203 sec
# k=21, accuracy = 100.0%, time = 0.02501654624938965 sec
# k=41, accuracy = 100.0%, time = 0.024016618728637695 sec
# k=61, accuracy = 99.30555555555556%, time = 0.03302192687988281 sec
# k=81, accuracy = 99.30555555555556%, time = 0.032022714614868164 sec
# k=101, accuracy = 98.61111111111111%, time = 0.027016878128051758 sec
# k=121, accuracy = 97.91666666666667%, time = 0.025015830993652344 sec
# k=141, accuracy = 97.22222222222223%, time = 0.027018308639526367 sec
# k=161, accuracy = 97.22222222222223%, time = 0.025016069412231445 sec
# k=181, accuracy = 97.22222222222223%, time = 0.02501845359802246 sec
